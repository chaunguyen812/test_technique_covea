# %%
# Importer les packages #
import pandas as pd
import numpy as np
import urllib.request
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import statsmodels
import statsmodels.api as sm
import scipy.stats as stats

# %%
# Read des données #
url = "https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20200416-115822/valeursfoncieres-2019.txt"
df = pd.read_csv(url, error_bad_lines=False, delimiter='|')
# Out:
# /Users/nguyenchau/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (18,23,24,26,28,29,31,33,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Print les 10 premiers lignes de data#
df.head(n=10)
# Out:
#    Code service CH  Reference document  1 Articles CGI  2 Articles CGI  \
# 0              NaN                 NaN             NaN             NaN
# 1              NaN                 NaN             NaN             NaN
# 2              NaN                 NaN             NaN             NaN
# 3              NaN                 NaN             NaN             NaN
# 4              NaN                 NaN             NaN             NaN
# 5              NaN                 NaN             NaN             NaN
# 6              NaN                 NaN             NaN             NaN
# 7              NaN                 NaN             NaN             NaN
# 8              NaN                 NaN             NaN             NaN
# 9              NaN                 NaN             NaN             NaN
#
#    3 Articles CGI  4 Articles CGI  5 Articles CGI  No disposition  \
# 0             NaN             NaN             NaN               1
# 1             NaN             NaN             NaN               1
# 2             NaN             NaN             NaN               1
# 3             NaN             NaN             NaN               1
# 4             NaN             NaN             NaN               1
# 5             NaN             NaN             NaN               1
# 6             NaN             NaN             NaN               1
# 7             NaN             NaN             NaN               1
# 8             NaN             NaN             NaN               1
# 9             NaN             NaN             NaN               1
#
#   Date mutation Nature mutation  ... Surface Carrez du 5eme lot  \
# 0    04/01/2019           Vente  ...                        NaN
# 1    04/01/2019           Vente  ...                        NaN
# 2    04/01/2019           Vente  ...                        NaN
# 3    08/01/2019           Vente  ...                        NaN
# 4    07/01/2019           Vente  ...                        NaN
# 5    03/01/2019           Vente  ...                        NaN
# 6    08/01/2019           Vente  ...                        NaN
# 7    08/01/2019           Vente  ...                        NaN
# 8    04/01/2019           Vente  ...                        NaN
# 9    04/01/2019           Vente  ...                        NaN
#
#    Nombre de lots Code type local   Type local Identifiant local  \
# 0               1             2.0  Appartement               NaN
# 1               2             2.0  Appartement               NaN
# 2               1             3.0   Dépendance               NaN
# 3               0             1.0       Maison               NaN
# 4               0             1.0       Maison               NaN
# 5               0             1.0       Maison               NaN
# 6               0             1.0       Maison               NaN
# 7               0             NaN          NaN               NaN
# 8               1             3.0   Dépendance               NaN
# 9               2             2.0  Appartement               NaN
#
#   Surface reelle bati  Nombre pieces principales Nature culture  \
# 0                20.0                        1.0            NaN
# 1                62.0                        3.0            NaN
# 2                 0.0                        0.0            NaN
# 3                90.0                        4.0              S
# 4               101.0                        5.0              S
# 5                88.0                        4.0              S
# 6                39.0                        2.0              S
# 7                 NaN                        NaN              L
# 8                 0.0                        0.0            NaN
# 9                69.0                        3.0            NaN
#
#   Nature culture speciale  Surface terrain
# 0                     NaN              NaN
# 1                     NaN              NaN
# 2                     NaN              NaN
# 3                     NaN            940.0
# 4                     NaN            490.0
# 5                     NaN            708.0
# 6                     NaN            631.0
# 7                     NaN            120.0
# 8                     NaN              NaN
# 9                     NaN              NaN
#
# [10 rows x 43 columns]

# %%
print(df.shape)# 2535791 lignes, 43 colonnes #
print(df.columns) # bis / ter / quater
# Out:
# (2535791, 43)
# Index(['Code service CH', 'Reference document', '1 Articles CGI',
#        '2 Articles CGI', '3 Articles CGI', '4 Articles CGI', '5 Articles CGI',
#        'No disposition', 'Date mutation', 'Nature mutation', 'Valeur fonciere',
#        'No voie', 'B/T/Q', 'Type de voie', 'Code voie', 'Voie', 'Code postal',
#        'Commune', 'Code departement', 'Code commune', 'Prefixe de section',
#        'Section', 'No plan', 'No Volume', '1er lot',
#        'Surface Carrez du 1er lot', '2eme lot', 'Surface Carrez du 2eme lot',
#        '3eme lot', 'Surface Carrez du 3eme lot', '4eme lot',
#        'Surface Carrez du 4eme lot', '5eme lot', 'Surface Carrez du 5eme lot',
#        'Nombre de lots', 'Code type local', 'Type local', 'Identifiant local',
#        'Surface reelle bati', 'Nombre pieces principales', 'Nature culture',
#        'Nature culture speciale', 'Surface terrain'],
#       dtype='object')

# %%
# Examiner le % des valeurs NA dans chaque variable #
num_sum = df.isna().sum()/df.shape[0]*100
num_sum
# Out:
# Code service CH               100.000000
# Reference document            100.000000
# 1 Articles CGI                100.000000
# 2 Articles CGI                100.000000
# 3 Articles CGI                100.000000
# 4 Articles CGI                100.000000
# 5 Articles CGI                100.000000
# No disposition                  0.000000
# Date mutation                   0.000000
# Nature mutation                 0.000000
# Valeur fonciere                 1.153920
# No voie                        40.446472
# B/T/Q                          95.684621
# Type de voie                   41.553898
# Code voie                       1.111645
# Voie                            1.118152
# Code postal                     1.116930
# Commune                         0.000000
# Code departement                0.000000
# Code commune                    0.000000
# Prefixe de section             94.998208
# Section                         0.002918
# No plan                         0.000000
# No Volume                      99.738701
# 1er lot                        69.137086
# Surface Carrez du 1er lot      91.282207
# 2eme lot                       93.568949
# Surface Carrez du 2eme lot     97.859682
# 3eme lot                       98.971445
# Surface Carrez du 3eme lot     99.794384
# 4eme lot                       99.635774
# Surface Carrez du 4eme lot     99.944199
# 5eme lot                       99.825419
# Surface Carrez du 5eme lot     99.975984
# Nombre de lots                  0.000000
# Code type local                46.630775
# Type local                     46.630775
# Identifiant local             100.000000
# Surface reelle bati            46.698486
# Nombre pieces principales      46.698486
# Nature culture                 31.270637
# Nature culture speciale        95.549594
# Surface terrain                31.270637
# dtype: float64

# %%
# Data_exploration et créer des sous-dataset# 
# Etape 1: Surprimer toutes les variables où le pourcentage des valeurs NA > 90%  #
df1 = df.drop(["Code service CH","Reference document","1 Articles CGI","2 Articles CGI",
               "3 Articles CGI","4 Articles CGI","5 Articles CGI","Nature culture speciale",
               "B/T/Q","Prefixe de section","No Volume","Surface Carrez du 1er lot","Surface Carrez du 2eme lot",
              "Surface Carrez du 2eme lot","Surface Carrez du 2eme lot","Surface Carrez du 3eme lot","Surface Carrez du 4eme lot",
              "Surface Carrez du 5eme lot","Identifiant local","Nature culture speciale","1er lot","2eme lot","3eme lot","4eme lot",
              "5eme lot","Date mutation","No voie","Type de voie","Nature culture","Surface terrain"],axis=1)

# %%
df1.head()
# Out:
#    No disposition Nature mutation Valeur fonciere Code voie             Voie  \
# 0               1           Vente        37220,00      2730     DE MONTHOLON
# 1               1           Vente       185100,00      1650  GEN DELESTRAINT
# 2               1           Vente       185100,00      1650  GEN DELESTRAINT
# 3               1           Vente       209000,00      0043   DES CHAMPAGNES
# 4               1           Vente       134900,00      A003        LE BIOLAY
#
#    Code postal                Commune Code departement  Code commune Section  \
# 0       1000.0        BOURG-EN-BRESSE                1            53      AI
# 1       1000.0        BOURG-EN-BRESSE                1            53      AM
# 2       1000.0        BOURG-EN-BRESSE                1            53      AM
# 3       1160.0                  PRIAY                1           314       E
# 4       1370.0  SAINT-ETIENNE-DU-BOIS                1           350      AA
#
#    No plan  Nombre de lots  Code type local   Type local  Surface reelle bati  \
# 0      298               1              2.0  Appartement                 20.0
# 1       95               2              2.0  Appartement                 62.0
# 2       95               1              3.0   Dépendance                  0.0
# 3     1676               0              1.0       Maison                 90.0
# 4       11               0              1.0       Maison                101.0
#
#    Nombre pieces principales
# 0                        1.0
# 1                        3.0
# 2                        0.0
# 3                        4.0
# 4                        5.0

# %%
# Examiner le nombre des catérogies et leur fréquence de la variable Nature mutation # 
df1["Nature mutation"].value_counts()
# Out:
# Vente                                 2308539
# Vente en l'état futur d'achèvement     185441
# Echange                                 27127
# Vente terrain à bâtir                    7806
# Adjudication                             4819
# Expropriation                            2059
# Name: Nature mutation, dtype: int64

# %%
# Examiner le nombre des catérogies et leur fréquence de la variable Type local #
df1["Type local"].value_counts()
# Out:
# Maison                                      515398
# Appartement                                 430975
# Dépendance                                  312480
# Local industriel. commercial ou assimilé     94479
# Name: Type local, dtype: int64

# %%
#Créer une sous-dataset pour les ventes (nature de la mutation=Vente, hors VEFA) 
#de maison et appartement (code type local=1 ou 2)
df2 = df1[(df1["Nature mutation"]== "Vente") & (df1["Code type local"]<=2)]
print(df2.shape)
# Out:
# (934965, 16)

# %%
# Examiner les valeurs NA de la dernier set #
df2.isna().sum()
# Out:
# No disposition                  0
# Nature mutation                 0
# Valeur fonciere              3608
# Code voie                       0
# Voie                           38
# Code postal                    52
# Commune                         0
# Code departement                0
# Code commune                    0
# Section                        31
# No plan                         0
# Nombre de lots                  0
# Code type local                 0
# Type local                      0
# Surface reelle bati            18
# Nombre pieces principales      18
# dtype: int64

# %%
df2.dtypes
# Out:
# No disposition                 int64
# Nature mutation               object
# Valeur fonciere               object
# Code voie                     object
# Voie                          object
# Code postal                  float64
# Commune                       object
# Code departement              object
# Code commune                   int64
# Section                       object
# No plan                        int64
# Nombre de lots                 int64
# Code type local              float64
# Type local                    object
# Surface reelle bati          float64
# Nombre pieces principales    float64
# dtype: object

# %%
# Surprimer les valeurs NA #
df2 = df2.dropna()

# %%
print(df2.shape)
#print(type(df2["Valeur fonciere"]))
# Out:
# (931218, 17)

# %%
# Transformer le type de la variable price en numérique #
price = []
for i in df2["Valeur fonciere"][:df2.shape[0]]:
    a = (i.split(",")[0])
    price.append(float(a))
df2["Valeur fonciere"] = price

# %%
# Summary des variables quantitatives #
df2.describe()
# Out:
#        No disposition  Valeur fonciere    Code postal   Code commune  \
# count   931218.000000     9.312180e+05  931218.000000  931218.000000
# mean         1.045327     1.350441e+06   54025.099849     209.192549
# std          0.516505     9.792117e+06   27491.440337     170.786982
# min          1.000000     0.000000e+00    1000.000000       1.000000
# 25%          1.000000     1.100000e+05   33000.000000      75.000000
# 50%          1.000000     1.790000e+05   56130.000000     169.000000
# 75%          1.000000     3.003500e+05   77500.000000     301.000000
# max         24.000000     2.086000e+09   97490.000000     909.000000
#
#              No plan  Nombre de lots  Code type local  Surface reelle bati  \
# count  931218.000000   931218.000000    931218.000000        931218.000000
# mean      353.473129        0.546305         1.450901            81.797441
# std       507.501926        0.863873         0.497584            45.991124
# min         1.000000        0.000000         1.000000             1.000000
# 25%        77.000000        0.000000         1.000000            50.000000
# 50%       192.000000        0.000000         1.000000            75.000000
# 75%       426.000000        1.000000         2.000000           102.000000
# max      9757.000000       24.000000         2.000000          1110.000000
#
#        Nombre pieces principales
# count              931218.000000
# mean                    3.477448
# std                     1.611235
# min                     0.000000
# 25%                     2.000000
# 50%                     3.000000
# 75%                     4.000000
# max                    67.000000

# %% [markdown]
# # Data_exploration

# %%
print(len(df2["Commune"].value_counts()))
print(len(df2["Code departement"].value_counts()))
# Out:
# 26994
# 99

# %%
# Groupe by par Commune # 
df_commue = df2.groupby(['Commune']).mean().reset_index()
# Top 10 les plus chers de valeur foncier par Commune #
df_commue.sort_values(by="Valeur fonciere",ascending=False).head(n=10)
#df_geo_neighbourhood[["Valeur fonciere","Surface reelle bati","Nomber pieces principales"]]
# Out:
#                    Commune  No disposition  Valeur fonciere  Code postal  \
# 18091         PLOUGOURVEST        1.000000     3.889747e+08  29400.00000
# 18131           PLOUZEVEDE        1.055556     2.318723e+08  29440.00000
# 4257      CASTELNAU LE LEZ        1.000000     1.313654e+08  34170.00000
# 15807  MONTFERRIER-SUR-LEZ        1.000000     1.312123e+08  34980.00000
# 19765               RUNGIS        1.000000     1.115889e+08  94150.00000
# 17867               PIGNAN        1.000000     1.098211e+08  34570.00000
# 13676           LONGJUMEAU        1.001197     6.587613e+07  91160.00000
# 26252            VILLEJUIF        1.001414     5.516288e+07  94800.00000
# 7740       ERAGNY-SUR-OISE        1.033233     5.356859e+07  95610.00000
# 14734              MAUGUIO        1.000000     5.063466e+07  34156.28866
#
#        Code commune     No plan  Nombre de lots  Code type local  \
# 18091         193.0  869.000000        0.000000         1.000000
# 18131         213.0  166.944444        0.000000         1.000000
# 4257           57.0  153.361011        0.155235         1.891697
# 15807         169.0  106.027778        0.750000         1.750000
# 19765          65.0  217.161538        0.684615         1.861538
# 17867         202.0  330.078431        0.137255         1.784314
# 13676         345.0  567.332735        0.197487         1.931777
# 26252          76.0  137.437058        0.990099         1.838755
# 7740          218.0  209.909366        0.764350         1.655589
# 14734         154.0  153.773196        0.546392         1.649485
#
#        Surface reelle bati  Nombre pieces principales  log_valeur_foncier
# 18091           107.333333                   4.111111           13.576089
# 18131           120.000000                   4.722222           12.597196
# 4257             66.462094                   2.960289           17.377392
# 15807            80.416667                   3.416667           17.425402
# 19765            52.030769                   2.384615           15.632983
# 17867            79.647059                   3.607843           16.514859
# 13676            68.587672                   3.429683           17.096331
# 26252            50.753890                   2.456860           14.037280
# 7740             69.921450                   3.205438           13.867308
# 14734            70.969072                   3.123711           14.092163

# %%
# Groupe by par Code departement #
df_depart = df2.groupby(['Code departement']).mean().reset_index()
# Top 10 les plus chers de valeur foncier par département #
df_depart.sort_values(by="Valeur fonciere",ascending=False).head(n=10)
# Out:
#    Code departement  No disposition  Valeur fonciere   Code postal  \
# 86               91        1.016469     7.267861e+06  91360.818233
# 20               22        1.030636     7.219309e+06  22332.206709
# 28               30        1.017511     5.740625e+06  30344.571781
# 17               18        2.787308     5.432663e+06  18151.988209
# 89               94        1.018758     4.231199e+06  94313.899257
# 32               34        1.023785     4.057723e+06  34380.286020
# 95               29        1.040260     3.571883e+06  29468.926393
# 88               93        1.008886     3.557196e+06  93314.237403
# 73               78        1.049751     3.174220e+06  78429.621965
# 93              973        1.028492     3.009144e+06  97319.524670
#
#     Code commune     No plan  Nombre de lots  Code type local  \
# 86    357.933081  349.980924        0.609134         1.557685
# 20    174.895917  446.062264        0.176338         1.283001
# 28    165.098868  481.125166        0.401290         1.473228
# 17    103.914345  303.275691        0.150503         1.432204
# 89     47.442106  153.159779        1.127595         1.769949
# 32    151.306951  367.719213        0.541060         1.481061
# 95    152.483530  389.517690        0.150468         1.185441
# 88     42.008363  302.610914        0.918043         1.722716
# 73    369.735167  352.365263        0.723324         1.568612
# 93      5.298124  465.555247        0.191105         1.490618
#
#     Surface reelle bati  Nombre pieces principales  log_valeur_foncier
# 86            78.025464                   3.543910           13.076781
# 20            87.843909                   3.716072           12.507741
# 28            80.900183                   3.381693           12.625753
# 17            80.107733                   3.465958           12.670531
# 89            63.160588                   2.955532           12.926076
# 32            75.978474                   3.259678           12.182179
# 95            91.653924                   3.941846           11.567934
# 88            61.566904                   2.972559           12.712329
# 73            82.608673                   3.574887           13.143651
# 93            74.070188                   3.013204           12.995917

# %% [markdown]
# # Data transformation

# %%
# Distribution de la variable Valeur fonciere et log(1+ Valeur foncier)
# On voit bien que cette variable suit la loi Log_normale, mais il faut excluse des valeurs outliers 
#dans cette variable

fig, axes = plt.subplots(1,3, figsize=(15,6))
sns.distplot(df2['Valeur fonciere'], ax=axes[0])
sns.distplot(np.log1p(df2['Valeur fonciere']), ax=axes[1])
axes[1].set_xlabel('log(1+Valeur foncier)')
sm.qqplot(np.log1p(df2['Valeur fonciere']), stats.norm, fit=True, line='45', ax=axes[2]);

# %%
# Créer une nouvelle variable log valeur foncier # 
df2["log_valeur_foncier"] = np.log1p(df2["Valeur fonciere"])

# %%
df2.head()
# Out:
#    No disposition Nature mutation  Valeur fonciere Code voie             Voie  \
# 0               1           Vente          37220.0      2730     DE MONTHOLON
# 1               1           Vente         185100.0      1650  GEN DELESTRAINT
# 3               1           Vente         209000.0      0043   DES CHAMPAGNES
# 4               1           Vente         134900.0      A003        LE BIOLAY
# 5               1           Vente         192000.0      0445   DES LIBELLULES
#
#    Code postal                Commune Code departement  Code commune Section  \
# 0       1000.0        BOURG-EN-BRESSE                1            53      AI
# 1       1000.0        BOURG-EN-BRESSE                1            53      AM
# 3       1160.0                  PRIAY                1           314       E
# 4       1370.0  SAINT-ETIENNE-DU-BOIS                1           350      AA
# 5       1340.0               ATTIGNAT                1            24      AI
#
#    No plan  Nombre de lots  Code type local   Type local  Surface reelle bati  \
# 0      298               1              2.0  Appartement                 20.0
# 1       95               2              2.0  Appartement                 62.0
# 3     1676               0              1.0       Maison                 90.0
# 4       11               0              1.0       Maison                101.0
# 5       94               0              1.0       Maison                 88.0
#
#    Nombre pieces principales  log_valeur_foncier
# 0                        1.0           10.524628
# 1                        3.0           12.128657
# 3                        4.0           12.250094
# 4                        5.0           11.812296
# 5                        4.0           12.165256

# %%
print(len(df2[df2["log_valeur_foncier"]<=9])) # Le nombre des observartions où les log_valeurs_fonciers <= 5
print(len(df2[df2["log_valeur_foncier"]>15])) # Le nombre des observartions où les log_valeurs_fonciers >= 15
# Out:
# 6109
# 35314

# %%
# Enlever les outliers # 
df_fn = df2[(df2["log_valeur_foncier"]>=9)& (df2["log_valeur_foncier"]<=15)]

# %%
df_fn.head()
# Out:
#    No disposition Nature mutation  Valeur fonciere Code voie             Voie  \
# 0               1           Vente          37220.0      2730     DE MONTHOLON
# 1               1           Vente         185100.0      1650  GEN DELESTRAINT
# 3               1           Vente         209000.0      0043   DES CHAMPAGNES
# 4               1           Vente         134900.0      A003        LE BIOLAY
# 5               1           Vente         192000.0      0445   DES LIBELLULES
#
#    Code postal                Commune Code departement  Code commune Section  \
# 0       1000.0        BOURG-EN-BRESSE                1            53      AI
# 1       1000.0        BOURG-EN-BRESSE                1            53      AM
# 3       1160.0                  PRIAY                1           314       E
# 4       1370.0  SAINT-ETIENNE-DU-BOIS                1           350      AA
# 5       1340.0               ATTIGNAT                1            24      AI
#
#    No plan  Nombre de lots  Code type local   Type local  Surface reelle bati  \
# 0      298               1              2.0  Appartement                 20.0
# 1       95               2              2.0  Appartement                 62.0
# 3     1676               0              1.0       Maison                 90.0
# 4       11               0              1.0       Maison                101.0
# 5       94               0              1.0       Maison                 88.0
#
#    Nombre pieces principales  log_valeur_foncier
# 0                        1.0           10.524628
# 1                        3.0           12.128657
# 3                        4.0           12.250094
# 4                        5.0           11.812296
# 5                        4.0           12.165256

# %%
fig = plt.figure(figsize = (15,10))
ax = fig.gca()
df_fn.hist(ax=ax)
plt.show()
# Out:
# /Users/nguyenchau/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fig=sm.qqplot((df_fn['log_valeur_foncier']), stats.norm, fit=True, line='45')
plt.figure(figsize=(16,12))
plt.show()

# %%
# Département: 75 Commune: ville (Paris)
# Département : Ile et Vilein (35), comune : Rennes , Saint Malo, Saint Briac...
# Section : un ou plus quatiers une ville # 
# Zone rurale: province (campagne) => le lieu où les grandes entreprises qui instellent 
# Zone urbaine : 
# Appartement peuvent avoir plus lots (Mimi a 2 lots: 1 lot pour appart et 1 lot pour la cave)
# Surface Carrez : 
#Surface réelle bâti : surface au sol entre les mur (prend pas en compte de surface de mur)
# Surface terrain :
